# %%
# %pylab inline
from matplotlib.colors import LogNorm
from mcstas_reader import McSim
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# h5py not found, modern NeXuS format will not be readable.

# %%
data=McSim('GISANS_events')['DETfin']

# %%
data.plot(norm=LogNorm(1e-2), cmap='gist_ncar', cbar=True)

# %%
McSim('GISANS_passthrough')['DETfin'].plot(norm=LogNorm(1e-2), cmap='gist_ncar', cbar=True)

# %%
McSim('GISANS_events_scattered')['DETfin'].plot(norm=LogNorm(1e-4, 1e4), cmap='gist_ncar', cbar=True)
title('McStas->BornAgain->McStas');

# %%
McSim('GISANS_test')['DETfin'].plot(norm=LogNorm(1e-4, 1e4), cmap='gist_ncar', cbar=True)
title('GISANS_test');

# %%
McSim('GISANS_tt')['DETfin'].plot(norm=LogNorm(), cmap='gist_ncar', cbar=True)
title('GISANS_tt');

# %%
McSim('GISANS_test')['DETfin'].info
# Out:
# {'Date': 'Tue Jun  6 17:11:55 2023 (1686064315)',
#  'type': 'array_2d(256, 256)',
#  'Source': 'GISANS_test (GISANS_test.instr)',
#  'component': 'DETfin',
#  'position': '0 0 110',
#  'title': 'PSD monitor',
#  'Ncount': '2000000',
#  'filename': 'PSDfin.txt',
#  'statistics': 'X0=-0.281553; dX=26.1063; Y0=-47.9232; dY=2.00668;',
#  'signal': 'Min=0; Max=6.7582e+07; Mean=48243.4;',
#  'values': '3.16168e+09 2.02332e+08 910274',
#  'xvar': 'X',
#  'yvar': 'Y',
#  'xlabel': 'X position [cm]',
#  'ylabel': 'Y position [cm]',
#  'zvar': 'I',
#  'zlabel': 'Signal per bin',
#  'xylimits': '-50 50 -50 50',
#  'variables': 'I I_err N'}

# %%
McSim('GISANS_events_scattered')['DETfin'].info
# Out:
# {'Date': 'Wed Jun  7 17:15:42 2023 (1686150942)',
#  'type': 'array_2d(256, 256)',
#  'Source': 'GISANS_test (GISANS_events_back.instr)',
#  'component': 'DETfin',
#  'position': '0 0 110',
#  'title': 'PSD monitor',
#  'Ncount': '11019898',
#  'filename': 'PSDfin.txt',
#  'statistics': 'X0=0.0206268; dX=3.23221; Y0=7.24158; dY=0.787481;',
#  'signal': 'Min=5.09511e-13; Max=27493.5; Mean=3.32482;',
#  'values': '217896 33978.8 768854',
#  'xvar': 'X',
#  'yvar': 'Y',
#  'xlabel': 'X position [cm]',
#  'ylabel': 'Y position [cm]',
#  'zvar': 'I',
#  'zlabel': 'Signal per bin',
#  'xylimits': '-50 50 -50 50',
#  'variables': 'I I_err N'}
